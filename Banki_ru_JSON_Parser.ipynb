# %%
import requests

# %%
def getSearchApiUrl():
  return "https://www.banki.ru/services/responses/list/ajax/";

# %%
def getSearchApiParameters(page = 1, commentType = None, rates = None, product = None, bank = None):
  return {
    'is_countable': 'on',
    'product': product,
    'type': commentType,
    'page': page,
    'rate[]': rates,
    'bank':bank
  }

# %% [markdown]
# https://curlconverter.com/python/

# %%
def getSearchApiHeaders():
  return {
      'accept': 'application/json',
      'accept-language': 'ru-RU,ru;q=0.9',
      'content-type': 'application/json',
      'referer': 'https://www.banki.ru/services/responses/list/product/deposits/',
      'sec-ch-ua': '"Google Chrome";v="123", "Not:A-Brand";v="8", "Chromium";v="123"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-origin',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
      'x-requested-with': 'XMLHttpRequest',
  }

# %%
def getSearchApiCookies():
  return {

  }

# %%
def SendRequest(commentType = None, rates = None, product = None, bank = None):
  url = getSearchApiUrl()
  params = getSearchApiParameters()
  headers = getSearchApiHeaders()
  cookies = getSearchApiCookies()

  response = requests.get(url, params=params, cookies=cookies, headers=headers)
  return response.json()

# %%
async def GetAllComments(commentType = None, rates = None, product = None, bank = None, maxPage = 3):
  resultList = []
  flag = True
  counter = 0
  while flag:
    counter+=1
    currentRequestResult = SendRequest(commentType, rates, product, bank)
    resultList = resultList + currentRequestResult['data']
    flag = currentRequestResult['hasMorePages'] and counter < maxPage
  return resultList

# %%
GetAllComments()
# Out:
# [{'id': 11432123,
#   'title': 'Закрытие ОМС',
#   'userName': 'user-332017697530',
#   'text': '<p>Появилась необходимость закрыть обезличенный металлический счет.</p>\r\n<p>В офис обратиться не было возможности, поэтому решила воспользоваться мобильным приложением.</p>\r\n<p>При попытке подать заявку на закрытие счета столкнулась, что нет такой функции.</p>\r\n<p>Обратилась в чат, специалист создал обращение, по результатам обращения меня направили в отделение банка, при том, что ранее было указано, что в офис обратиться нет возможности.</p>\r\n<p>Решила проверить возможность закрытия счета в ЛК на сайте, у меня получилось, счет на следующий день закрылся.</p>\r\n<p>Вопрос: почему сотрудник чата не мог подсказать, что закрытие возможно через сайт?</p>',
#   'grade': 3,
#   'commentCount': 2,
#   'isCountable': True,
#   'dateCreate': '2024-04-08 11:01:55',
#   'resolutionIsApproved': True,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nМы взяли в работу ваш отзыв. Обязательно все проверим и чуть позже ответим.\r\n\r\nС уважением,\r\nМТС Банк.\r\n',
#   'agentId': 6055,
#   'company': {'id': 6055,
#    'code': 'mts-bank',
#    'name': 'МТС Банк',
#    'url': 'mts-bank',
#    'logo': '//static2.banki.ru/ugc/7f/af/89/78/6055.svg',
#    'squareLogo': '//static2.banki.ru/ugc/b4/10/85/f8/6055.png',
#    'phone': [{'phone': '8 800 250-05-20',
#      'phone_description': 'служба поддержки держателей банковских карт'}],
#    'region': 'Москва',
#    'address': '115432, г.\xa0Москва, просп. Андропова, д.\xa018, корп. 1'}},
#  {'id': 11431690,
#   'title': 'Не зачислены деньги отправленные по СПб',
#   'userName': 'alexeevich487@gmail.com',
#   'text': '<p>Мной переведены на счёт деньги из Райфайзен банка. По выписке отобразилось, что деньги отправлены, но баланс не увеличился. Пропали 1000 рублей. <a href="https://drive.google.com/file/d/1qDOX--iH94qynffJ80Fuvv_KREgk6TRI/view?usp=drivesdk" target="_self">Видео выпис</a>. Я позвонил в службу поддержки и деньги не зачислили. Если какие то технические проблемы то заранее об этом сообщайте, а не тогда когда деньги уже переведены.\xa0</p>',
#   'grade': 1,
#   'commentCount': 3,
#   'isCountable': True,
#   'dateCreate': '2024-04-08 00:16:41',
#   'resolutionIsApproved': True,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nСпасибо, что отметили решение ситуации. Извините, что сумма отразилась не сразу. Мы учтем все ваши замечания в дальнейшей работе, чтобы использование сервиса оставляло только приятные впечатления. \r\n\r\nС уважением,\r\nМТС Банк',
#   'agentId': 6055,
#   'company': {'id': 6055,
#    'code': 'mts-bank',
#    'name': 'МТС Банк',
#    'url': 'mts-bank',
#    'logo': '//static2.banki.ru/ugc/7f/af/89/78/6055.svg',
#    'squareLogo': '//static2.banki.ru/ugc/b4/10/85/f8/6055.png',
#    'phone': [{'phone': '8 800 250-05-20',
#      'phone_description': 'служба поддержки держателей банковских карт'}],
#    'region': 'Москва',
#    'address': '115432, г.\xa0Москва, просп. Андропова, д.\xa018, корп. 1'}},
#  {'id': 11428342,
#   'title': 'Профессиональная и быстрая поддержка',
#   'userName': 'user-192717494313',
#   'text': '<p>Уже несколько лет являюсь клиентом МТС Банка, и хочу выразить благодарность банку за высокий уровень поддержки в онлайн-чате! Сотрудники банка всегда отвечают быстро и прилагают все усилия, чтобы помочь, будь то оформление кредита, вклада, просто какая-либо консультация по операцям по счету, и это очень важно для меня как клиента. Особенно рекомендую банк тем, у кого нет в городе офиса, так как у МТС Банка очень хорошо развито дистанционное обслуживание.</p>',
#   'grade': 5,
#   'commentCount': 3,
#   'isCountable': True,
#   'dateCreate': '2024-04-05 14:07:23',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Добрый день!\r\n\r\nСпасибо за отличную оценку!\r\n\r\nС наилучшими пожеланиями,\r\nМТС Банк',
#   'agentId': 6055,
#   'company': {'id': 6055,
#    'code': 'mts-bank',
#    'name': 'МТС Банк',
#    'url': 'mts-bank',
#    'logo': '//static2.banki.ru/ugc/7f/af/89/78/6055.svg',
#    'squareLogo': '//static2.banki.ru/ugc/b4/10/85/f8/6055.png',
#    'phone': [{'phone': '8 800 250-05-20',
#      'phone_description': 'служба поддержки держателей банковских карт'}],
#    'region': 'Москва',
#    'address': '115432, г.\xa0Москва, просп. Андропова, д.\xa018, корп. 1'}},
#  {'id': 11428088,
#   'title': 'Обман!',
#   'userName': 'user-176117667969',
#   'text': '<p>Получаю на карту данного банка пособия по уходу за ребенком , отправляет их МТС и как выяснилось отправляют их как обычный перевод без кода операции!  Пришли пособия и всё средства списали автоматически в счет кредита , на горячей линии сказали что подключено было АВТОМАТИЧЕСКИ БЕЗ МОЕЙ ПРОСЬБЫ автосписание с карты. \r\n\r\nПри этом они не прислали уведомление о том что поступили средства, хотя о переводах с моей карты  уведомление приходят и уведомления с ненужной рекламой они тоже не забывают отправлять по 1000 раз на дню . Вернуть деньги отказываются , оставили без средств .</p>',
#   'grade': 1,
#   'commentCount': 1,
#   'isCountable': True,
#   'dateCreate': '2024-04-05 12:06:50',
#   'resolutionIsApproved': True,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nСегодня связались с вами и уточнили детали. Как все проверим, вернемся с ответом на ресурс.\r\n\r\nС уважением,\r\nМТС Банк\r\n\r\nUPD:\r\n\r\nМы вернули сегодня выплату на виртуальную карту. В телефонном разговоре вы подтвердили возврат. Также мы рассказали, как отменить автоматическое списание. Рады, что смогли помочь!\r\n\r\nС уважением,\r\nМТС Банк',
#   'agentId': 6055,
#   'company': {'id': 6055,
#    'code': 'mts-bank',
#    'name': 'МТС Банк',
#    'url': 'mts-bank',
#    'logo': '//static2.banki.ru/ugc/7f/af/89/78/6055.svg',
#    'squareLogo': '//static2.banki.ru/ugc/b4/10/85/f8/6055.png',
#    'phone': [{'phone': '8 800 250-05-20',
#      'phone_description': 'служба поддержки держателей банковских карт'}],
#    'region': 'Москва',
#    'address': '115432, г.\xa0Москва, просп. Андропова, д.\xa018, корп. 1'}},
#  {'id': 11427683,
#   'title': 'Огромный срок закрытия кредитной карты',
#   'userName': 'user5907854',
#   'text': '<p>Добрый день! Столкнулся с неприятной для себя проблемой. Около года назад открыл в банке Уралсиб кредитную карту с беспроцентным периодом и около года ей пользовался, периодически закрывая задолженность, и запуская заново беспроцентный период (ставка по кредиту - 37.86% , пользоваться картой вне беспроцентного периода я категорически не планировал). В настоящий момент, я беру ипотечный кредит, и решил избавиться от активов, которые в кредитной истории считаются, как обременение. Закрыть данную карту через приложение нельзя, необходим визит в офис банка. \r\n\r\nПосетил офис на Таганской, где меня вежливо и оперативно обслужили, подписал договор на закрытие карты. На следующий день, данная карта исчезла из мобильного приложения. Спустя неделю, я обнаружил, что данная карта так и отображается на ресурсах проверки кредитного состояния, как активная. В чате мобильного приложения банка оператор мне сообщил, что договор закроется через 45 дней, и закрыть его ранее нет никакой возможности. И все это время карта будет, таким же образом отображаться. \r\n\r\nУ меня вопрос : этот договор лично министр финансов закрывает, и поэтому требуется такое количество времени? На самом деле, понятно, что банк расчитывает на то, что клиент, вдруг передумает закрывать счет, и вернется к кредитованию. И на интересы клиента в данной ситуации, банку абсолютно наплевать. Вот, уж действительно : " вход - 1 рубль, выход - 2 рубля". В общем, я в дальнейшем, не хочу иметь более никаких дел с данным банком и другим, тоже не рекомендую.\xa0\xa0\xa0\xa0</p>',
#   'grade': 2,
#   'commentCount': 1,
#   'isCountable': True,
#   'dateCreate': '2024-04-05 08:34:14',
#   'resolutionIsApproved': True,
#   'agentAnswerText': 'Добрый день!\r\nБлагодарим за отзыв. Насколько нам известно, с вами уже связался сотрудник банка для предоставления комментариев по вашему отзыву. Для нас важно, чтобы ситуация была решена, поэтому просим вас подтвердить этот факт в рамках данного отзыва. \r\nС уважением, Банк Уралсиб.',
#   'agentId': 63520,
#   'company': {'id': 63520,
#    'code': 'uralsib',
#    'name': 'Уралсиб',
#    'url': 'uralsib',
#    'logo': '//static3.banki.ru/ugc/bd/4b/42/dd/63520.svg',
#    'squareLogo': '//static3.banki.ru/ugc/07/33/dd/92/63520.png',
#    'phone': [{'phone': '8 800 250-57-57',
#      'phone_description': 'единая справочная служба'},
#     {'phone': '8 800 700-77-16',
#      'phone_description': 'поддержка юридических лиц и ИП'}],
#    'region': 'Москва',
#    'address': '119048, г.\xa0Москва, ул.\xa0Ефремова, д.\xa08'}},
#  {'id': 11427576,
#   'title': 'Сегодня перевыпуск карт не нужен,чат разъяснил',
#   'userName': 'user-709010056488',
#   'text': '<p>Здравствуйте!Я как пользователь продуктов банка и более десяти лет,соответственно имею дебетовые карты и у меня их четыре,еще до многих изменений в тарифе я их ряд выпустил,была нужда,они и сейчас служат на благо.Возникли вопросы по их активности и есть ли необходимость перевыпуска,запросил чат и поставил все эти вопросы.Обратился 04 апреля 2024г., 09:11,ответили мгновенно,оператор Екатерина за непродолжительное время проверила их активность,в норме и дала понять,что сегодня карты все бессрочные,в том числе и кредитные,удобно,экономит время на походах в банк за заменой и это началось с пандемией,таково было распоряжение ЦБ .</p>\r\n<p>Оператор быстро отреагировал на вопросы,осуществил проверку,дал разъяснение по все вопросам,за что консультацию оцениваю на отлично,вежливо и доброжелательно завершили диалог и без какой либо агрессивной рекламы продуктов,а это важно,что диалог вëлся по существу задаваемых вопросов.Вопрос решëн!</p>\r\n<p></p>\r\n<p>Скрины переписки в чате,отправил Вам на эл.почту.Благодарю за внимание!</p>',
#   'grade': 5,
#   'commentCount': 1,
#   'isCountable': True,
#   'dateCreate': '2024-04-05 05:18:46',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Добрый день.\r\n\r\nСпасибо, что нашли время для написания такого замечательного отзыва!\r\n\r\nМы с особым вниманием относимся не только к замечаниям в наш адрес, но и к благодарностям. Благодаря им мы понимаем, что вы чувствуете себя в нашем Банке комфортно.\r\n\r\nС нашей стороны мы продолжим радовать вас нашими продуктами и теплым общением.\r\n\r\nС уважением , эксперт Алёна',
#   'agentId': 6764,
#   'company': {'id': 6764,
#    'code': 'homecreditbank',
#    'name': 'Хоум Банк',
#    'url': 'homecreditbank',
#    'logo': '//static2.banki.ru/ugc/45/e9/7e/a2/6764.svg',
#    'squareLogo': '//static2.banki.ru/ugc/c2/30/33/8a/6764.png',
#    'phone': [{'phone': '(495) 785-82-22', 'phone_description': ''}],
#    'region': 'Москва',
#    'address': '125040, г.\xa0Москва, ул.\xa0Правды, д.\xa08, корп. 1'}},
#  {'id': 11427245,
#   'title': 'Оперативность и проффесионализм',
#   'userName': 'user-244716585950',
#   'text': '<ul>\r\n<li>27 марта 2024 года в 18 часов 48 минут мною был задан вопрос оператора-консультанта Ивану.Суть вопроса была:"Какая оплата и покупки входят в категории кешбэка "Транспорт" и "Автоуслуги"?Не имея информации о том,что входит в эти категории можно было произвести их ошибочный выбор на следующий месяц,исключая другие предложенные.Кокретный и в полном объеме ответ последовал незамедлительно,что помогло мне не теряя лишнего времени определиться с категориями.Выражаю благодарность сотрудникам Озон банка за оперативность и проффесиональную подкованность.</li>\r\n</ul>',
#   'grade': 5,
#   'commentCount': 1,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 20:36:13',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте.\r\n\r\nСпасибо за отзыв и высокую оценку. Рады, что вам нравится наш сервис!\r\n\r\nБудем благодарны, если в комментариях приложите скриншот диалога в чате или отправите его на responses@banki.ru со ссылкой на ваш отзыв. Это поможет модераторам убедиться, что вы написали отзыв о реальной ситуации и администрация сайта сможет его засчитать.\r\n',
#   'agentId': 11752949,
#   'company': {'id': 11752949,
#    'code': 'ecombank',
#    'name': 'Ozon Банк',
#    'url': 'ecombank',
#    'logo': '//static2.banki.ru/ugc/a8/7e/27/c5/11752949.svg',
#    'squareLogo': '//static2.banki.ru/ugc/71/90/06/59/11752949.png',
#    'phone': [{'phone': '(495) 215-24-08', 'phone_description': None}],
#    'region': '',
#    'address': '123112, г. Москва, Пресненская набережная, д. 10'}},
#  {'id': 11427089,
#   'title': 'Активация карты ozon banka',
#   'userName': 'user-202213285057',
#   'text': '<p>Пользуюсь озон картой для оплаты покупок на озон уже давно, однажды решила заказать пластиковую карту, чтоб еще получать дополнительный кэшбэк с покупок вне маркетплэйса озон. Карту доставили домой и я благополучно про нее забыла. Недавно снова обратила внимание на хороший кэшбэк на покупки вне озон и решила воспользоваться, но пластиковая карта была неактивна. \r\n\r\nВ приложении озон кнопка активировать уже пропала и я 01.04.2024 в 11:12 обратилась в поддержку через чат в приложении озон. Мне ответила оператор Дарья и выслала инструкцию по активации. Правда по этой инструкции кнопка активации, тоже не нашлась, но Дарья видимо поняла, что случай тяжелый и отправила ссылку на активацию 😁. В итоге все случилось, спасибо поддержке банка за терпение 👍</p>',
#   'grade': 5,
#   'commentCount': 0,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 18:54:08',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте.\r\n\r\nСпасибо за отзыв и высокую оценку. Рады, что вам нравится наш сервис!\r\n\r\nБудем благодарны, если в комментариях приложите скриншот диалога в чате или отправите его на responses@banki.ru со ссылкой на ваш отзыв. Это поможет модераторам убедиться, что вы написали отзыв о реальной ситуации и администрация сайта сможет его засчитать.\r\n',
#   'agentId': 11752949,
#   'company': {'id': 11752949,
#    'code': 'ecombank',
#    'name': 'Ozon Банк',
#    'url': 'ecombank',
#    'logo': '//static2.banki.ru/ugc/a8/7e/27/c5/11752949.svg',
#    'squareLogo': '//static2.banki.ru/ugc/71/90/06/59/11752949.png',
#    'phone': [{'phone': '(495) 215-24-08', 'phone_description': None}],
#    'region': '',
#    'address': '123112, г. Москва, Пресненская набережная, д. 10'}},
#  {'id': 11427049,
#   'title': 'Поразила клиентоориентированность сотрудников',
#   'userName': 'Kesha33',
#   'text': '<p>Пишу честно и от души. Была с подругой в офисе банка во Владимире на ул. Горького, д.56 в сб 30.03.2024.</p>\r\n<p>Помещение тесное, народу много, места для всех не хватает. Работали две девушки Яна и Ирина. Поразило их очень чуткое и внимательное обращение с клиентами. Народ приходит разный, в основном не подготовленный, некоторые ругаются с порога не разобравшись. У девушек к каждому индивидуальный подход. Терпеливо и доброжелательно объясняли и повторяли, предлагали различные варианты с комментариями, почему именно это будет правильнее и выгоднее. Особо нервные клиенты даже успокаивались.</p>\r\n<p>Я пришла за второй кредитной картой. По непонятной причине карту union pay банк не одобрил. Мне было сразу предложено попробовать подать заявку на Умную карту. Ее одобрили. Пока шло оформление, мне рассказали обо всех ньюансах этой кредитки: условия бесплатного обслуживания, страховка, уведомления. Все вопросы девушки ловили с лету. Это редко бывает, когда у сотрудников имеются такие глубокие знания продуктов банка. А я пользователь матерый, карточки от многих банков имею. Подруга получила дебетовку.</p>\r\n<p>В 16.00 офис должен был закрыться, но подошло еще несколько человек. Всех пустили и только после этого заперли офис. Мы с подругой выходили из отделения последние в шестом часу вечера. Честно, это поразило. Девчонки работали с улыбкой до последнего клиента, ни одним мускулом не показывая, что рабочий день уже давно кончился. Еще и улыбаться силы оставались.\xa0</p>\r\n<p>Вот, честно, к самому банку у меня претензий много, например, не выплаченный до сих пор акционный кешбек за февраль. Разбираюсь с этим по телефону, жду решения.\xa0</p>\r\n<p>А вот девчонкам спасибо огромное! Именно на таких сотрудниках, работающих "в полях" строится репутация компании, именно с них начинается путь клиента и складывается первое впечатление об организации. Яна, Ирина, спасибо вам огромное за профессионализм, доброжелательность и человечность.</p>',
#   'grade': 4,
#   'commentCount': 0,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 18:30:29',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nМы постоянно работаем над тем, чтобы быть лучше. Нам важно, чтобы клиенты оставались довольны. \r\nНадеемся на длительное сотрудничество.\r\n\r\nС уважением,\r\nКоманда экспертов Газпромбанка',
#   'agentId': 2764,
#   'company': {'id': 2764,
#    'code': 'gazprombank',
#    'name': 'Газпромбанк',
#    'url': 'gazprombank',
#    'logo': '//static4.banki.ru/ugc/47/e1/79/0a/2764.svg',
#    'squareLogo': '//static4.banki.ru/ugc/6d/43/60/de/2764.png',
#    'phone': [{'phone': '400', 'phone_description': None},
#     {'phone': '8 800 300-60-90', 'phone_description': None},
#     {'phone': '8 800 100-07-01', 'phone_description': None},
#     {'phone': '* 6090',
#      'phone_description': 'для абонентов МТС, Билайн, Мегафон, Tele2 и Мотив'}],
#    'region': 'Москва',
#    'address': '117420, г.\xa0Москва, ул.\xa0Наметкина, д.\xa016, корп. 1.'}},
#  {'id': 11426836,
#   'title': 'Встреча с представителем банка',
#   'userName': 'user-328311252865',
#   'text': '<p>2.04.2024 г. у меня была встреча с представителем банка М-ко Дмитрием А..</p>\r\n<p>В назначенный день представитель банка Дмитрий за 2 часа до приезда позвонил мне и сориентировал по времени приезда. Мне пришлось сменить адрес доставки, так как я был на работе. Дмитрий приехал в назначенное время и доставил заказанную карту. Подробно ответил на все интересующие меня вопросы. Все вежливо, пунктуально и четко. Молодец!!!</p>',
#   'grade': 5,
#   'commentCount': 2,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 16:15:40',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nСпасибо, что нашли время оставить отзыв и поставили максимальную оценку.\r\nНапишите, пожалуйста, в комментариях более подробно об обслуживании.\r\nКакие вопросы вы задавали представителю? \r\nСколько времени длилась встреча?\r\n\r\nЭта информация будет полезна администраторам портала при принятии решения о зачете отзыва.\r\n\r\nС уважением,\r\nКоманда экспертов Газпромбанка',
#   'agentId': 2764,
#   'company': {'id': 2764,
#    'code': 'gazprombank',
#    'name': 'Газпромбанк',
#    'url': 'gazprombank',
#    'logo': '//static4.banki.ru/ugc/47/e1/79/0a/2764.svg',
#    'squareLogo': '//static4.banki.ru/ugc/6d/43/60/de/2764.png',
#    'phone': [{'phone': '400', 'phone_description': None},
#     {'phone': '8 800 300-60-90', 'phone_description': None},
#     {'phone': '8 800 100-07-01', 'phone_description': None},
#     {'phone': '* 6090',
#      'phone_description': 'для абонентов МТС, Билайн, Мегафон, Tele2 и Мотив'}],
#    'region': 'Москва',
#    'address': '117420, г.\xa0Москва, ул.\xa0Наметкина, д.\xa016, корп. 1.'}},
#  {'id': 11426813,
#   'title': 'Быстро помогли в официальной группе',
#   'userName': 'user-13176875',
#   'text': '<p>Необходима была информация по дубль карте,можно ли вообще выпустить,т е у меня есть дебетовая карта,но возникла необходимость в дополнительной карте к основной и одним счётом. Я, обратилась в официальную группу  с вопросом по карте. Очень быстро,мне ответил специалист в 14:34 ( 04 апреля 2024), который в рамках чата решил мой вопрос и пояснил,можно оформить дополнительную карту к основной. У дополнительной карты номер карты отличается, однако, счет у карт один.\xa0</p>\r\n<p>Оформление доступно в любом офисе банка и в интернет-банке, мобильном приложении ПСБ. Решением моего вопроса, Я осталась довольна, выражаю благодарность. Дополнение к отзыву отправлено Вам на электронную почту.</p>',
#   'grade': 5,
#   'commentCount': 0,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 16:06:26',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nСпасибо за обратную связь и оценку! Рады, что наш коллега помог с Вашим вопросом. \r\nОбязательно передадим ему слова благодарности.',
#   'agentId': 5306,
#   'company': {'id': 5306,
#    'code': 'promsvyazbank',
#    'name': 'ПСБ',
#    'url': 'promsvyazbank',
#    'logo': '//static3.banki.ru/ugc/b1/d8/4d/82/5306.svg',
#    'squareLogo': '//static3.banki.ru/ugc/96/12/2c/95/5306.png',
#    'phone': [{'phone': '8 800 333-03-03',
#      'phone_description': 'для физических лиц, звонок по России бесплатный'},
#     {'phone': '8 800 333-25-50',
#      'phone_description': 'для юридических лиц, звонок по России бесплатный'}],
#    'region': 'Москва',
#    'address': '109052, г.\xa0Москва, ул.\xa0Смирновская, д.\xa010, стр. 22'}},
#  {'id': 11426658,
#   'title': 'Оказали помощь в официальной группе',
#   'userName': 'user-13176875',
#   'text': '<p>В мобильном приложении банка,Я не нашла,как сделать пожертвование в определенный фонд ( Подари жизнь) ,а хотела помочь людям. Обратилась в официальную группу,где моментально ответил специалист в 17:06 ( 02 апреля 2024),который в рамках чата решил мой вопрос и пояснил,что можно</p>\r\n<p>по реквизитам до 100 000 руб. в мес. без комиссии (для зарплатных клиентов). Далее 0,6% от суммы (мин. 20 руб., макс. 1 500 руб.). Лимитов нет. В разделе «Платежи»"По реквизитам" - "Рублевый перевод". Решением моего вопроса,Я осталась довольна, выражаю благодарность специалисту. Дополнение к отзыву отправлено Вам на электронную почту.</p>',
#   'grade': 5,
#   'commentCount': 0,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 14:32:23',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nБлагодарим за отзыв о нашем специалисте! Мы рады, что он смог помочь вам разобраться с Вашим вопросом. \r\nПередадим ему Вашу благодарность :)',
#   'agentId': 5306,
#   'company': {'id': 5306,
#    'code': 'promsvyazbank',
#    'name': 'ПСБ',
#    'url': 'promsvyazbank',
#    'logo': '//static3.banki.ru/ugc/b1/d8/4d/82/5306.svg',
#    'squareLogo': '//static3.banki.ru/ugc/96/12/2c/95/5306.png',
#    'phone': [{'phone': '8 800 333-03-03',
#      'phone_description': 'для физических лиц, звонок по России бесплатный'},
#     {'phone': '8 800 333-25-50',
#      'phone_description': 'для юридических лиц, звонок по России бесплатный'}],
#    'region': 'Москва',
#    'address': '109052, г.\xa0Москва, ул.\xa0Смирновская, д.\xa010, стр. 22'}},
#  {'id': 11426644,
#   'title': 'Банк кормит завтраками, (компенсация комиссии за карту Юнион Пэй)',
#   'userName': 'Uralgeo',
#   'text': '<p>28 декабря 2023 года, открыл премиум карту Юнион пэй даймонд , в этот же закинул на неё 106000 рублей , 30 декабря за выпуск карты списали 5000 рублей, но есть акция по которой комиссия возвращается , если выполнить одно из условий, я держал остаток больше 100 000 рублей в течении 60 дней.\r\n\r\nУсловие выполнил в конце февраля , компенсация должна была прийти до 29 марта,  звоню на линию говорят ждите до 2 апреля, потом до 4 апреля. На дворе 4 апреля , денег так и нет! Очень не приятное знакомство с банком.</p>',
#   'grade': 1,
#   'commentCount': 1,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 14:22:19',
#   'resolutionIsApproved': True,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nВзяли ваш вопрос в работу. Уточним информацию и вернемся с ответом.\r\n\r\nС уважением,\r\nКоманда экспертов Газпромбанка',
#   'agentId': 2764,
#   'company': {'id': 2764,
#    'code': 'gazprombank',
#    'name': 'Газпромбанк',
#    'url': 'gazprombank',
#    'logo': '//static4.banki.ru/ugc/47/e1/79/0a/2764.svg',
#    'squareLogo': '//static4.banki.ru/ugc/6d/43/60/de/2764.png',
#    'phone': [{'phone': '400', 'phone_description': None},
#     {'phone': '8 800 300-60-90', 'phone_description': None},
#     {'phone': '8 800 100-07-01', 'phone_description': None},
#     {'phone': '* 6090',
#      'phone_description': 'для абонентов МТС, Билайн, Мегафон, Tele2 и Мотив'}],
#    'region': 'Москва',
#    'address': '117420, г.\xa0Москва, ул.\xa0Наметкина, д.\xa016, корп. 1.'}},
#  {'id': 11426511,
#   'title': 'Претензия Уралсиб (внесение наличных на карту "Прибыль")',
#   'userName': '164b1df65b1',
#   'text': '<p>В городе нет ни одного банкомата Уралсиба. Но меня уверили, что смогу пользоваться банкоматами банков-партнеров. Внес 02.04.2024 г.\xa0</p>\r\n<p><br>1) 150 000 руб. на дебетовую карту через банкомат ВТБ  <br>2) через 15 мин внес 100 000 руб. через банкомат Альфа банка <br><br>И при зачислении только зайдя в приложение узнал что сняли комиссию. На экране банкоматов  было указано, что внесение на карту Мир банка Уралсиб будет без комиссии.</p>\r\n<p>Пользовался теми тарифами, что были указаны на сайте (с 1 апреля они поменялись), но по той ссылке, где они  были информация не поменялась (подробнее в претензии)</p>\r\n<p>до 100 000 - без комиссии (ВТБ, Альфа, Росбанк и ДР)</p>\r\n<p>до 150 000 - без комиссии ВТБ.</p>\r\n<p></p>\r\n<p>Прошу вернуть комиссии:</p>\r\n<p>750 руб за внесении в ВТБ</p>\r\n<p>1500 руб за внесение в Альфе</p>\r\n<p></p>\r\n<p>Если бы я знал, что будут такие комиссии  - то не вносил бы деньги через эти банкоматы.</p>\r\n<p>Оставлена претензия в банковском приложении К-240402-000143</p>\r\n<p></p>',
#   'grade': 1,
#   'commentCount': 3,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 12:53:43',
#   'resolutionIsApproved': True,
#   'agentAnswerText': 'Добрый день!\r\nБлагодарим за отзыв. По результатам проведенной проверки был выявлен факт некорректной консультации вас сотрудником контакт-центра банка. Сообщаем, что банком приняты соответствующие меры, направленные на усовершенствование клиентского сервиса и повышение качества консультирования, с сотрудниками проведена разъяснительная беседа в целях недопущения подобных ситуаций в будущем и назначено дополнительно обучение.\r\nС целью урегулирования вашего отзыва банком принято решение о возврате удержанной комиссии. Возврат денежных средств будет произведен в течение 3-х рабочих дней.\r\nПриносим вам свои извинения за причиненные неудобства. Для нас важно, чтобы ситуация была решена, поэтому просим вас подтвердить этот факт в рамках данного отзыва. \r\nС уважением, Банк Уралсиб.',
#   'agentId': 63520,
#   'company': {'id': 63520,
#    'code': 'uralsib',
#    'name': 'Уралсиб',
#    'url': 'uralsib',
#    'logo': '//static3.banki.ru/ugc/bd/4b/42/dd/63520.svg',
#    'squareLogo': '//static3.banki.ru/ugc/07/33/dd/92/63520.png',
#    'phone': [{'phone': '8 800 250-57-57',
#      'phone_description': 'единая справочная служба'},
#     {'phone': '8 800 700-77-16',
#      'phone_description': 'поддержка юридических лиц и ИП'}],
#    'region': 'Москва',
#    'address': '119048, г.\xa0Москва, ул.\xa0Ефремова, д.\xa08'}},
#  {'id': 11426402,
#   'title': 'Списание денежных средств',
#   'userName': 'user-449917655952',
#   'text': '<p>23 марта 2024 г. В 00.27, пока я спала с моей карты сняли денежные средства в размере 1861 р, якобы оплата МТС услуг. Но на мтс не подписана, нигде не зарегистрирована не была и данные своей карты не оставляла и не давала. В ответ на моё обращение в приложении Сбербанка онлайн, мне постоянно отвечают, что нужно подождать сначала до 4 апреля, а сегодня написали что уже до 10 ареля, в результате одни обещания и средства не возвращаются. Наши данные в этом банке не защищены, не вижу смысла сотрудничать с данным банком!</p>',
#   'grade': 5,
#   'commentCount': 1,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 11:48:36',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Добрый день!\r\n\r\nСпасибо, что рассказали, что вопрос решился, деньги вернули и перевыпустили карту. Рекомендую также обратиться в поддержку, чтобы списаний больше не было 🙏\r\n\r\nС уважением,\r\nМария Александрова\r\nСбер',
#   'agentId': 322,
#   'company': {'id': 322,
#    'code': 'sberbank',
#    'name': 'Сбербанк',
#    'url': 'sberbank',
#    'logo': '//static3.banki.ru/ugc/30/46/f1/aa/322.svg',
#    'squareLogo': '//static3.banki.ru/ugc/9d/12/0b/81/322.png',
#    'phone': [{'phone': '900', 'phone_description': 'единая справочная служба'},
#     {'phone': '0321',
#      'phone_description': 'для корпоративных клиентов; бесплатные звонки с мобильных телефонов (Билайн, Мегафон, МТС, Tele2) на территории России'},
#     {'phone': '8 800 555-55-50',
#      'phone_description': 'единая справочная служба; для бесплатных звонков абонентов сотовых операторов МТС, Билайн, Мегафон, Tele2, Yota и Мотив из всех регионов России'},
#     {'phone': '8 800 555-57-77',
#      'phone_description': 'для корпоративных клиентов; бесплатные звонки с городских телефонов на территории России'}],
#    'region': 'Москва',
#    'address': '117997, г.\xa0Москва, ул.\xa0Вавилова, д.\xa019'}},
#  {'id': 11426256,
#   'title': 'Обмен валют',
#   'userName': 'user-105117655040',
#   'text': '<p>Доброго вечера .  Визит  в отделение  был сегодня , 3 апреля , время - 14:35 . Обслуживала меня кассир Дарья, очень вежливая .\xa0</p>\r\n<p>Я покупала иностранную валюту . Кстати , от Дарьи узнала про доллары старого и нового образца , и про риски связанные с первыми . За высокий уровень компетенции и сервиса - ставлю 5.\xa0</p>\r\n<p>Обслужили меня за 5 минут, в очереди я стояла где-то 7, так что все очень быстро )))</p>\r\n<p>Банк, в основном , насколько я поняла, специализируется на обмене валют .</p>\r\n<p>Потому что , который раз вижу лучший курс продажи и покупки  валюты именно у него . Анализирую , соответственно  на сервисе банки.ру.)) Отличное, чистое, светлое  отделение с коммуникабельными гостеприимными и профессиональными сотрудниками. Очень удобно  , что недалеко от дома , очень удобная локация, недалеко от метро и выезд на ленинградское шоссе .</p>',
#   'grade': 5,
#   'commentCount': 0,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 10:32:33',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте!\r\nБольшое спасибо, очень приятно получать обратную связь! Мы всегда вам рады.',
#   'agentId': 193364,
#   'company': {'id': 193364,
#    'code': 'kamkombank',
#    'name': 'КАМКОМБАНК',
#    'url': 'kamkombank',
#    'logo': '//static4.banki.ru/ugc/7e/d7/1d/33/193364.svg',
#    'squareLogo': '//static4.banki.ru/ugc/fe/36/73/ce/193364.png',
#    'phone': [{'phone': '8 800 200-04-38',
#      'phone_description': 'единая справочная служба'}],
#    'region': 'Набережные Челны',
#    'address': '423800, Республика Татарстан, г.\xa0Набережные Челны, ул.\xa0Гидростроителей, д.\xa021'}},
#  {'id': 11426217,
#   'title': 'Благодарность премиум-менеджеру',
#   'userName': 'user-428713933128',
#   'text': '<p>Добрый день!</p>\r\n<p>Сегодня 03.04.2024 была на обслуживание у премиум менеджера -Кристины,по поводу консультации по открытию вклада или накопительного счёта.</p>\r\n<p>Кристина,все очень подробно рассказала про накопительный счёт (процентная ставка 15%),по вкладам тоже (ставка 16.2%.)</p>\r\n<p>Очень понравилось обслуживание,угостили конфетками.</p>\r\n<p>Я ушла думать по поводу открытия,но вернусь,тк скоро заканчивается вклад в другом банке и приду размещать деньги .</p>',
#   'grade': 5,
#   'commentCount': 0,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 10:08:26',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Добрый день!\r\n\r\nСпасибо за положительный отзыв о работе нашего Банка!\r\n\r\nНам приятно слышать, что Вы отмечаете позитивные моменты в наших взаимоотношениях!\r\n\r\nВсегда готовы к получению обратной связи и рады Вам помочь!\r\n\r\nМы будем Вам также очень признательны если Вы в комментарии к отзыву расскажете немного подробнее о том, как именно и чем Вам помогли наши сотрудники, а также о качестве сервиса в Банке.\r\n\r\nС уважением,\r\nВаш АО "Банк ДОМ.РФ"',
#   'agentId': 2237,
#   'company': {'id': 2237,
#    'code': 'domrfbank',
#    'name': 'Банк ДОМ.РФ',
#    'url': 'domrfbank',
#    'logo': '//static4.banki.ru/ugc/09/61/83/70/2237.svg',
#    'squareLogo': '//static4.banki.ru/ugc/9f/7d/7a/84/2237.png',
#    'phone': [{'phone': '8 800 775-86-86 ',
#      'phone_description': 'единая справочная служба'}],
#    'region': 'Москва',
#    'address': '125009, г.\xa0Москва, ул.\xa0Воздвиженка, д.\xa010'}},
#  {'id': 11426111,
#   'title': 'Спасибо!',
#   'userName': 'user-562817654099',
#   'text': '<p>Я являюсь клиентом банка очень давно, в феврале меня пригласили в офис для замены пенсионной карты. Я пришла в офис, попала к Арине, она выдала мне карту, рассказала что у карты есть бесконтактная оплата и кешбек 5% на определенные категории и 1% на все покупки, небольшой кешбек, но может покрыть расходы на смс. Ещё она предложила последить за старым кешбеком, который копится отдельно и сказала что бы я пришла до 10 апреля. \r\n\r\nИ вот сегодня 4 апреля я пришла в банк, Арина посмотрела что кешбек почти не идет и выяснила у меня, что я редко пользуюсь картой. Она предложила оформить карту Скидка везде по которой будет 1% с каждой покупки оставаться на карте, а за онлайн покупки 3%. Ещё Арина поменяла мне старый накопительный счет на новый МТС Счет и теперь я буду получать вместо 5% - 15% первые два месяца. Я очень благодарна за человеческое отношение в этом офисе, всегда все объяснят, все быстро сделают, нет очереди.\xa0</p>',
#   'grade': 5,
#   'commentCount': 0,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 09:01:37',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Добрый день!\r\n\r\nМы рады, что Арина помогла вам с оформлением новой карты и накопительного счета на более выгодных условиях. С удовольствием поблагодарим её за хорошую работу. Будем стараться, чтобы обслуживание всегда соответствовало вашей оценке.\r\n\r\nС уважением,\r\nМТС Банк',
#   'agentId': 6055,
#   'company': {'id': 6055,
#    'code': 'mts-bank',
#    'name': 'МТС Банк',
#    'url': 'mts-bank',
#    'logo': '//static2.banki.ru/ugc/7f/af/89/78/6055.svg',
#    'squareLogo': '//static2.banki.ru/ugc/b4/10/85/f8/6055.png',
#    'phone': [{'phone': '8 800 250-05-20',
#      'phone_description': 'служба поддержки держателей банковских карт'}],
#    'region': 'Москва',
#    'address': '115432, г.\xa0Москва, просп. Андропова, д.\xa018, корп. 1'}},
#  {'id': 11425947,
#   'title': 'Оплата кредита',
#   'userName': 'user-391217652476',
#   'text': '<p>Никогда и никому за всю свою жизнь не писал отзывов, но сегодня сделаю исключение. Я обслуживаюсь в МТС банке города Благовещенска по ул. Калинина, 52 немало лет и за всë  это время у меня сложился только положительный опыт контактирования с банком. Прихожу ежемесячно оплачивать кредит, как обычно, через кассу, мне так удобнее. 2 апреля 2024 года в кассе меня встретила девушка приятной наружности, если не ошибаюсь ее зовут Инесса (фамилию не запомнил)</p>\r\n<p>Так вот она мне посоветовала установить приложение МТС банка, что сразу же и сделали. Далее научила пользоваться этим приложением и не посещая банк оплачивать кредит, а с моими больными ногами это очень важно. Выражаю благодарность сотруднице кассы за ангельское терпение, ведь нам, пенсионерам, сложно даются современные технологии и порой приходится по нескольку раз переспрашивать одно и тоже.</p>',
#   'grade': 5,
#   'commentCount': 0,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 03:16:42',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Добрый день!\r\n\r\nОчень приятно, что вы уделили время и рассказали о своих впечатлениях. Обязательно похвалим Инессу за доброжелательное отношение и индивидуальный подход. Будьте уверены, что, приходя к нам, вы всегда можете рассчитывать на нашу помощь. Благодарим за отзыв и наивысший балл.\r\n\r\nС уважением,\r\nМТС Банк',
#   'agentId': 6055,
#   'company': {'id': 6055,
#    'code': 'mts-bank',
#    'name': 'МТС Банк',
#    'url': 'mts-bank',
#    'logo': '//static2.banki.ru/ugc/7f/af/89/78/6055.svg',
#    'squareLogo': '//static2.banki.ru/ugc/b4/10/85/f8/6055.png',
#    'phone': [{'phone': '8 800 250-05-20',
#      'phone_description': 'служба поддержки держателей банковских карт'}],
#    'region': 'Москва',
#    'address': '115432, г.\xa0Москва, просп. Андропова, д.\xa018, корп. 1'}},
#  {'id': 11425847,
#   'title': 'Помощь в переходе на другой тариф',
#   'userName': 'user-225215160845',
#   'text': '<p>По телевизору часто показывают про кэшбек начисляемый по банковской карте до 30 процентов. Узнать какой кэшбек у меня решил узнать в мобильном приложении. 3 апреля 2024 в 8:58 Юлия присоединилась к беседе и написала в чате,что кэшбек по карте не предусмотрен. На вопрос есть техническая возможность переделать ее еа карту с кэшбеком написала инструкцию как самому без похода в отделение банка переделать. Переход на тариф бесплатный, сообщила Юлия. Выражаю благодарность оператору Юлии за помощь в решении моего вопроса.</p>',
#   'grade': 5,
#   'commentCount': 1,
#   'isCountable': True,
#   'dateCreate': '2024-04-03 23:03:11',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nБлагодарим за отзыв о нашем специалисте! Мы рады, что Юлия смогла помочь Вам разобраться с Вашим вопросом. Передадим ей Вашу благодарность.',
#   'agentId': 5306,
#   'company': {'id': 5306,
#    'code': 'promsvyazbank',
#    'name': 'ПСБ',
#    'url': 'promsvyazbank',
#    'logo': '//static3.banki.ru/ugc/b1/d8/4d/82/5306.svg',
#    'squareLogo': '//static3.banki.ru/ugc/96/12/2c/95/5306.png',
#    'phone': [{'phone': '8 800 333-03-03',
#      'phone_description': 'для физических лиц, звонок по России бесплатный'},
#     {'phone': '8 800 333-25-50',
#      'phone_description': 'для юридических лиц, звонок по России бесплатный'}],
#    'region': 'Москва',
#    'address': '109052, г.\xa0Москва, ул.\xa0Смирновская, д.\xa010, стр. 22'}},
#  {'id': 11425504,
#   'title': 'Детально консультируют',
#   'userName': 'user-380916861058',
#   'text': '<p>Всегда вносил деньги на кредитку Хоум банка  в офисе а теперь решил узнать какая будет комиссия за переводы с карты Газпромбанка и обратился в официальную группу  03.04.2024 где менеджер рассказал как посмотреть все тарифы но я не понял и менеджер снова объяснил.Спасибо за такой подход к клиентам\xa0</p>\r\n<p>Дополнение к отзыву отправлены на электронную почту.</p>',
#   'grade': 5,
#   'commentCount': 0,
#   'isCountable': True,
#   'dateCreate': '2024-04-03 18:38:16',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте! \r\n\r\nБлагодарим за высокую оценку. Рады, что мы на верном пути.\r\nНадеемся на длительное сотрудничество с вами.\r\n\r\nС уважением,\r\nКоманда экспертов Газпромбанка',
#   'agentId': 2764,
#   'company': {'id': 2764,
#    'code': 'gazprombank',
#    'name': 'Газпромбанк',
#    'url': 'gazprombank',
#    'logo': '//static4.banki.ru/ugc/47/e1/79/0a/2764.svg',
#    'squareLogo': '//static4.banki.ru/ugc/6d/43/60/de/2764.png',
#    'phone': [{'phone': '400', 'phone_description': None},
#     {'phone': '8 800 300-60-90', 'phone_description': None},
#     {'phone': '8 800 100-07-01', 'phone_description': None},
#     {'phone': '* 6090',
#      'phone_description': 'для абонентов МТС, Билайн, Мегафон, Tele2 и Мотив'}],
#    'region': 'Москва',
#    'address': '117420, г.\xa0Москва, ул.\xa0Наметкина, д.\xa016, корп. 1.'}},
#  {'id': 11425502,
#   'title': 'Спасибо представителю',
#   'userName': 'user-962717649276',
#   'text': '<p>редко пишу отзывы , но в это раз захотела отблагодарить представителю девушку Д-ву Олесю , утром со мной связалась для подтверждение встречи , я подтвердила , но потом меня срочно вызвали на работу , я написала девушке , что уеду , девушка предложила подъехать на работу либо дождаться вечера , очень приятно , что девушка готова была пойти на встречу и подъехать к тому месту , где мне удобно ,\xa0</p>\r\n<p>в итоге я освободилась приехала домой к 19.20 , девушка подъехала оформили документы и активировали карту , открыли накопительный счет , очень выгодное предложение 16.5 процентов .</p>\r\n<p>Спасибо представителю за качественное обслуживание\xa0</p>',
#   'grade': 5,
#   'commentCount': 2,
#   'isCountable': True,
#   'dateCreate': '2024-04-03 18:37:28',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nБлагодарим вас за положительный отзыв.\r\nНам очень приятно, что что вы отметили преимущества обслуживания в Газпромбанке.\r\nБудем благодарны, если дополните отзыв в комментариях. \r\nУточните, пожалуйста, дату получения карты? \r\nНа какие вопросы представитель помог получить ответ? \r\n\r\nЭта информация будет полезна администраторам портала при принятии решения о зачете отзыва.\r\n\r\nС уважением,\r\nКоманда экспертов Газпромбанка',
#   'agentId': 2764,
#   'company': {'id': 2764,
#    'code': 'gazprombank',
#    'name': 'Газпромбанк',
#    'url': 'gazprombank',
#    'logo': '//static4.banki.ru/ugc/47/e1/79/0a/2764.svg',
#    'squareLogo': '//static4.banki.ru/ugc/6d/43/60/de/2764.png',
#    'phone': [{'phone': '400', 'phone_description': None},
#     {'phone': '8 800 300-60-90', 'phone_description': None},
#     {'phone': '8 800 100-07-01', 'phone_description': None},
#     {'phone': '* 6090',
#      'phone_description': 'для абонентов МТС, Билайн, Мегафон, Tele2 и Мотив'}],
#    'region': 'Москва',
#    'address': '117420, г.\xa0Москва, ул.\xa0Наметкина, д.\xa016, корп. 1.'}},
#  {'id': 11425493,
#   'title': 'Отделение закрыто, но подробной информации нет',
#   'userName': 'user-151217649300',
#   'text': '<p>Отделение СБ в г.Брянск, закрылось на ремонт, банкоматы также не работают. При этом в Яндекс.картах есть примечание о временном закрытии отделения, но банкомат обозначены как работающие 24 часа, хотя на самом деле они не работают (скриншот прилагается). Объявление о закрытии на ремонт - отдельная песня: мало того, что в нем очепятка, так хоть бы указали, куда обращаться на период закрытия! \r\n\r\nПри мне пришла бабулька, которая до сих пор получает пенсию на сберкнижку (да, представьте себе, таких бабулек-дедулек тысячи) и у меня спрашивала, что же ей теперь делать, где ещё Сбербанк поблизости. Ну ладно, я ещё могу найти другой банкомат (хотя и обидно было, поверив картам, потерять время), но напишите по-людски для пожилых - где находится ближайшее отделение, на какой остановке, как доехать, какой режим работы. Ну не могут они это в интернете найти, не у всех дети-внуки есть.</p>\r\n<p><a href="https://ibb.co/JpMHHRz" target="_self">Объявление </a>\xa0</p>\r\n<p><a href="https://ibb.co/8YwSDWQ" target="_self">Яндекс.карты</a>\xa0</p>',
#   'grade': 1,
#   'commentCount': 2,
#   'isCountable': True,
#   'dateCreate': '2024-04-03 18:32:59',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nПодобрать удобный для себя офис или банкомат можно в Сбербанк Онлайн или на нашем сайте: https://www.sberbank.com/ru/oib?tab=vsp Там всегда актуальная информация.\r\nЧто касается ошибки в объявлении, напишите, пожалуйста, полный адрес в комментариях, попрошу коллег исправить\r\n\r\nС уважением, \r\nМария Александрова\r\nСбер',
#   'agentId': 322,
#   'company': {'id': 322,
#    'code': 'sberbank',
#    'name': 'Сбербанк',
#    'url': 'sberbank',
#    'logo': '//static3.banki.ru/ugc/30/46/f1/aa/322.svg',
#    'squareLogo': '//static3.banki.ru/ugc/9d/12/0b/81/322.png',
#    'phone': [{'phone': '900', 'phone_description': 'единая справочная служба'},
#     {'phone': '0321',
#      'phone_description': 'для корпоративных клиентов; бесплатные звонки с мобильных телефонов (Билайн, Мегафон, МТС, Tele2) на территории России'},
#     {'phone': '8 800 555-55-50',
#      'phone_description': 'единая справочная служба; для бесплатных звонков абонентов сотовых операторов МТС, Билайн, Мегафон, Tele2, Yota и Мотив из всех регионов России'},
#     {'phone': '8 800 555-57-77',
#      'phone_description': 'для корпоративных клиентов; бесплатные звонки с городских телефонов на территории России'}],
#    'region': 'Москва',
#    'address': '117997, г.\xa0Москва, ул.\xa0Вавилова, д.\xa019'}},
#  {'id': 11425285,
#   'title': 'Самый отвратительный банк!',
#   'userName': 'DELETED',
#   'text': '<p>Никогда таких проблем с другими банками не имела, как с МТС Банком! Оформляла рефинансирование, сделала ЧДП 12.03.2024, все списалось вовремя и в том объеме, в котором было заявлено, но потом начались какие-то проблемы. \r\n\r\nПосле ЧДП у меня образовалась по непонятным причинам просроченная задолженность, какие-то неуплаченные % и еще пени на них стали начислять считаю каждый день! Мне стали звонить сотрудники, сыпаться грозные СМС. \r\n\r\nЯ написала в поддержку и с сотрудником онлайн-чата создали заявку 14.03.2024 , которую долго не могли решить и решают по сей день. 01.04.2024 я получила СМС о том, что заявка исполнена, но ситуация не изменилась! В ЛК так же "светится" строка "просрочен платеж". Мне как продолжали звонить и сыпаться грозные СМС, так и продолжают до сих пор! \r\n\r\nПочему я должна страдать из-за технической ошибки этого банка? Скоро будет очередной ежемесячный платеж и первым, то у меня спишут, это эти незаконно начисленные проценты и пени! Почему из-за технической ошибки банка я должна платить неоьоснованно начисленную сумму процентов и пеней из своего кармана? Абсолютное возмущение и полное нежелание дальше быть клиентом МТС Банка.\xa0</p>',
#   'grade': 2,
#   'commentCount': 1,
#   'isCountable': True,
#   'dateCreate': '2024-04-03 16:38:46',
#   'resolutionIsApproved': True,
#   'agentAnswerText': 'Здравствуйте, Kh.V.A!\r\n\r\nВозьмем некоторое время, чтобы все проверить по кредиту. И чуть позже вернемся с ответом.\r\n\r\nС уважением,\r\nМТС Банк',
#   'agentId': 6055,
#   'company': {'id': 6055,
#    'code': 'mts-bank',
#    'name': 'МТС Банк',
#    'url': 'mts-bank',
#    'logo': '//static2.banki.ru/ugc/7f/af/89/78/6055.svg',
#    'squareLogo': '//static2.banki.ru/ugc/b4/10/85/f8/6055.png',
#    'phone': [{'phone': '8 800 250-05-20',
#      'phone_description': 'служба поддержки держателей банковских карт'}],
#    'region': 'Москва',
#    'address': '115432, г.\xa0Москва, просп. Андропова, д.\xa018, корп. 1'}},
#  {'id': 11425245,
#   'title': 'Не начислена выплата по акции "Бонусы за использование Unionpay Газпромбанка.2"',
#   'userName': 'user-583017621082',
#   'text': '<p>22 ноября 2023 заказала карту Unionpay. Списали 5000 рублей за использование. В ноябре, декабре и январе были совершены покупки от 10000 рублей. Ожидала, что в феврале начислят бонус в 5000 рублей согласно условиям акции, но этого не произошло. На вопрос о том, почему не был выплачен бонус, в чате просто скинули условия акции (причём некорректные для моей карты) и тут же закрыли вопрос. Я ведь потому и спросила, что условия изучила, а причины невыплаты мне так и остались неясными. \r\n\r\nДалее последовали попытки дозвониться до банка (ожидание просто зашкаливало, а чат просто несколько дней не брал вопросы в работу), наконец удалось это сделать, там оператор подтвердила, что условия акции были выполнены и зарегистрировала обращение 1650355.  Через 10 дней мне пришёл ответ, что по техническим причинам я не вошла в список участников акции, что банк работает над этим и начислит выплату до конца месяца, если условия были выполнены. Март закончился, выплаты нет, информации также не поступало. Очень разочарована взаимодействием с банком и отсутствием адекватной обратной связи.\xa0</p>',
#   'grade': 1,
#   'commentCount': 3,
#   'isCountable': True,
#   'dateCreate': '2024-04-03 16:14:23',
#   'resolutionIsApproved': True,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nНам жаль, что вам пришлось столкнуться с такими сложностями. \r\nПроверим информацию по вашему обращению и обязательно вернемся с ответом.\r\n\r\nС уважением,\r\nКоманда экспертов Газпромбанка',
#   'agentId': 2764,
#   'company': {'id': 2764,
#    'code': 'gazprombank',
#    'name': 'Газпромбанк',
#    'url': 'gazprombank',
#    'logo': '//static4.banki.ru/ugc/47/e1/79/0a/2764.svg',
#    'squareLogo': '//static4.banki.ru/ugc/6d/43/60/de/2764.png',
#    'phone': [{'phone': '400', 'phone_description': None},
#     {'phone': '8 800 300-60-90', 'phone_description': None},
#     {'phone': '8 800 100-07-01', 'phone_description': None},
#     {'phone': '* 6090',
#      'phone_description': 'для абонентов МТС, Билайн, Мегафон, Tele2 и Мотив'}],
#    'region': 'Москва',
#    'address': '117420, г.\xa0Москва, ул.\xa0Наметкина, д.\xa016, корп. 1.'}},
#  {'id': 11432123,
#   'title': 'Закрытие ОМС',
#   'userName': 'user-332017697530',
# ...
#    'squareLogo': '//static4.banki.ru/ugc/9f/7d/7a/84/2237.png',
#    'phone': [{'phone': '8 800 775-86-86 ',
#      'phone_description': 'единая справочная служба'}],
#    'region': 'Москва',
#    'address': '125009, г.\xa0Москва, ул.\xa0Воздвиженка, д.\xa010'}},
#  {'id': 11426111,
#   'title': 'Спасибо!',
#   'userName': 'user-562817654099',
#   'text': '<p>Я являюсь клиентом банка очень давно, в феврале меня пригласили в офис для замены пенсионной карты. Я пришла в офис, попала к Арине, она выдала мне карту, рассказала что у карты есть бесконтактная оплата и кешбек 5% на определенные категории и 1% на все покупки, небольшой кешбек, но может покрыть расходы на смс. Ещё она предложила последить за старым кешбеком, который копится отдельно и сказала что бы я пришла до 10 апреля. \r\n\r\nИ вот сегодня 4 апреля я пришла в банк, Арина посмотрела что кешбек почти не идет и выяснила у меня, что я редко пользуюсь картой. Она предложила оформить карту Скидка везде по которой будет 1% с каждой покупки оставаться на карте, а за онлайн покупки 3%. Ещё Арина поменяла мне старый накопительный счет на новый МТС Счет и теперь я буду получать вместо 5% - 15% первые два месяца. Я очень благодарна за человеческое отношение в этом офисе, всегда все объяснят, все быстро сделают, нет очереди.\xa0</p>',
#   'grade': 5,
#   'commentCount': 0,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 09:01:37',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Добрый день!\r\n\r\nМы рады, что Арина помогла вам с оформлением новой карты и накопительного счета на более выгодных условиях. С удовольствием поблагодарим её за хорошую работу. Будем стараться, чтобы обслуживание всегда соответствовало вашей оценке.\r\n\r\nС уважением,\r\nМТС Банк',
#   'agentId': 6055,
#   'company': {'id': 6055,
#    'code': 'mts-bank',
#    'name': 'МТС Банк',
#    'url': 'mts-bank',
#    'logo': '//static2.banki.ru/ugc/7f/af/89/78/6055.svg',
#    'squareLogo': '//static2.banki.ru/ugc/b4/10/85/f8/6055.png',
#    'phone': [{'phone': '8 800 250-05-20',
#      'phone_description': 'служба поддержки держателей банковских карт'}],
#    'region': 'Москва',
#    'address': '115432, г.\xa0Москва, просп. Андропова, д.\xa018, корп. 1'}},
#  {'id': 11425947,
#   'title': 'Оплата кредита',
#   'userName': 'user-391217652476',
#   'text': '<p>Никогда и никому за всю свою жизнь не писал отзывов, но сегодня сделаю исключение. Я обслуживаюсь в МТС банке города Благовещенска по ул. Калинина, 52 немало лет и за всë  это время у меня сложился только положительный опыт контактирования с банком. Прихожу ежемесячно оплачивать кредит, как обычно, через кассу, мне так удобнее. 2 апреля 2024 года в кассе меня встретила девушка приятной наружности, если не ошибаюсь ее зовут Инесса (фамилию не запомнил)</p>\r\n<p>Так вот она мне посоветовала установить приложение МТС банка, что сразу же и сделали. Далее научила пользоваться этим приложением и не посещая банк оплачивать кредит, а с моими больными ногами это очень важно. Выражаю благодарность сотруднице кассы за ангельское терпение, ведь нам, пенсионерам, сложно даются современные технологии и порой приходится по нескольку раз переспрашивать одно и тоже.</p>',
#   'grade': 5,
#   'commentCount': 0,
#   'isCountable': True,
#   'dateCreate': '2024-04-04 03:16:42',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Добрый день!\r\n\r\nОчень приятно, что вы уделили время и рассказали о своих впечатлениях. Обязательно похвалим Инессу за доброжелательное отношение и индивидуальный подход. Будьте уверены, что, приходя к нам, вы всегда можете рассчитывать на нашу помощь. Благодарим за отзыв и наивысший балл.\r\n\r\nС уважением,\r\nМТС Банк',
#   'agentId': 6055,
#   'company': {'id': 6055,
#    'code': 'mts-bank',
#    'name': 'МТС Банк',
#    'url': 'mts-bank',
#    'logo': '//static2.banki.ru/ugc/7f/af/89/78/6055.svg',
#    'squareLogo': '//static2.banki.ru/ugc/b4/10/85/f8/6055.png',
#    'phone': [{'phone': '8 800 250-05-20',
#      'phone_description': 'служба поддержки держателей банковских карт'}],
#    'region': 'Москва',
#    'address': '115432, г.\xa0Москва, просп. Андропова, д.\xa018, корп. 1'}},
#  {'id': 11425847,
#   'title': 'Помощь в переходе на другой тариф',
#   'userName': 'user-225215160845',
#   'text': '<p>По телевизору часто показывают про кэшбек начисляемый по банковской карте до 30 процентов. Узнать какой кэшбек у меня решил узнать в мобильном приложении. 3 апреля 2024 в 8:58 Юлия присоединилась к беседе и написала в чате,что кэшбек по карте не предусмотрен. На вопрос есть техническая возможность переделать ее еа карту с кэшбеком написала инструкцию как самому без похода в отделение банка переделать. Переход на тариф бесплатный, сообщила Юлия. Выражаю благодарность оператору Юлии за помощь в решении моего вопроса.</p>',
#   'grade': 5,
#   'commentCount': 1,
#   'isCountable': True,
#   'dateCreate': '2024-04-03 23:03:11',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nБлагодарим за отзыв о нашем специалисте! Мы рады, что Юлия смогла помочь Вам разобраться с Вашим вопросом. Передадим ей Вашу благодарность.',
#   'agentId': 5306,
#   'company': {'id': 5306,
#    'code': 'promsvyazbank',
#    'name': 'ПСБ',
#    'url': 'promsvyazbank',
#    'logo': '//static3.banki.ru/ugc/b1/d8/4d/82/5306.svg',
#    'squareLogo': '//static3.banki.ru/ugc/96/12/2c/95/5306.png',
#    'phone': [{'phone': '8 800 333-03-03',
#      'phone_description': 'для физических лиц, звонок по России бесплатный'},
#     {'phone': '8 800 333-25-50',
#      'phone_description': 'для юридических лиц, звонок по России бесплатный'}],
#    'region': 'Москва',
#    'address': '109052, г.\xa0Москва, ул.\xa0Смирновская, д.\xa010, стр. 22'}},
#  {'id': 11425504,
#   'title': 'Детально консультируют',
#   'userName': 'user-380916861058',
#   'text': '<p>Всегда вносил деньги на кредитку Хоум банка  в офисе а теперь решил узнать какая будет комиссия за переводы с карты Газпромбанка и обратился в официальную группу  03.04.2024 где менеджер рассказал как посмотреть все тарифы но я не понял и менеджер снова объяснил.Спасибо за такой подход к клиентам\xa0</p>\r\n<p>Дополнение к отзыву отправлены на электронную почту.</p>',
#   'grade': 5,
#   'commentCount': 0,
#   'isCountable': True,
#   'dateCreate': '2024-04-03 18:38:16',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте! \r\n\r\nБлагодарим за высокую оценку. Рады, что мы на верном пути.\r\nНадеемся на длительное сотрудничество с вами.\r\n\r\nС уважением,\r\nКоманда экспертов Газпромбанка',
#   'agentId': 2764,
#   'company': {'id': 2764,
#    'code': 'gazprombank',
#    'name': 'Газпромбанк',
#    'url': 'gazprombank',
#    'logo': '//static4.banki.ru/ugc/47/e1/79/0a/2764.svg',
#    'squareLogo': '//static4.banki.ru/ugc/6d/43/60/de/2764.png',
#    'phone': [{'phone': '400', 'phone_description': None},
#     {'phone': '8 800 300-60-90', 'phone_description': None},
#     {'phone': '8 800 100-07-01', 'phone_description': None},
#     {'phone': '* 6090',
#      'phone_description': 'для абонентов МТС, Билайн, Мегафон, Tele2 и Мотив'}],
#    'region': 'Москва',
#    'address': '117420, г.\xa0Москва, ул.\xa0Наметкина, д.\xa016, корп. 1.'}},
#  {'id': 11425502,
#   'title': 'Спасибо представителю',
#   'userName': 'user-962717649276',
#   'text': '<p>редко пишу отзывы , но в это раз захотела отблагодарить представителю девушку Д-ву Олесю , утром со мной связалась для подтверждение встречи , я подтвердила , но потом меня срочно вызвали на работу , я написала девушке , что уеду , девушка предложила подъехать на работу либо дождаться вечера , очень приятно , что девушка готова была пойти на встречу и подъехать к тому месту , где мне удобно ,\xa0</p>\r\n<p>в итоге я освободилась приехала домой к 19.20 , девушка подъехала оформили документы и активировали карту , открыли накопительный счет , очень выгодное предложение 16.5 процентов .</p>\r\n<p>Спасибо представителю за качественное обслуживание\xa0</p>',
#   'grade': 5,
#   'commentCount': 2,
#   'isCountable': True,
#   'dateCreate': '2024-04-03 18:37:28',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nБлагодарим вас за положительный отзыв.\r\nНам очень приятно, что что вы отметили преимущества обслуживания в Газпромбанке.\r\nБудем благодарны, если дополните отзыв в комментариях. \r\nУточните, пожалуйста, дату получения карты? \r\nНа какие вопросы представитель помог получить ответ? \r\n\r\nЭта информация будет полезна администраторам портала при принятии решения о зачете отзыва.\r\n\r\nС уважением,\r\nКоманда экспертов Газпромбанка',
#   'agentId': 2764,
#   'company': {'id': 2764,
#    'code': 'gazprombank',
#    'name': 'Газпромбанк',
#    'url': 'gazprombank',
#    'logo': '//static4.banki.ru/ugc/47/e1/79/0a/2764.svg',
#    'squareLogo': '//static4.banki.ru/ugc/6d/43/60/de/2764.png',
#    'phone': [{'phone': '400', 'phone_description': None},
#     {'phone': '8 800 300-60-90', 'phone_description': None},
#     {'phone': '8 800 100-07-01', 'phone_description': None},
#     {'phone': '* 6090',
#      'phone_description': 'для абонентов МТС, Билайн, Мегафон, Tele2 и Мотив'}],
#    'region': 'Москва',
#    'address': '117420, г.\xa0Москва, ул.\xa0Наметкина, д.\xa016, корп. 1.'}},
#  {'id': 11425493,
#   'title': 'Отделение закрыто, но подробной информации нет',
#   'userName': 'user-151217649300',
#   'text': '<p>Отделение СБ в г.Брянск, закрылось на ремонт, банкоматы также не работают. При этом в Яндекс.картах есть примечание о временном закрытии отделения, но банкомат обозначены как работающие 24 часа, хотя на самом деле они не работают (скриншот прилагается). Объявление о закрытии на ремонт - отдельная песня: мало того, что в нем очепятка, так хоть бы указали, куда обращаться на период закрытия! \r\n\r\nПри мне пришла бабулька, которая до сих пор получает пенсию на сберкнижку (да, представьте себе, таких бабулек-дедулек тысячи) и у меня спрашивала, что же ей теперь делать, где ещё Сбербанк поблизости. Ну ладно, я ещё могу найти другой банкомат (хотя и обидно было, поверив картам, потерять время), но напишите по-людски для пожилых - где находится ближайшее отделение, на какой остановке, как доехать, какой режим работы. Ну не могут они это в интернете найти, не у всех дети-внуки есть.</p>\r\n<p><a href="https://ibb.co/JpMHHRz" target="_self">Объявление </a>\xa0</p>\r\n<p><a href="https://ibb.co/8YwSDWQ" target="_self">Яндекс.карты</a>\xa0</p>',
#   'grade': 1,
#   'commentCount': 2,
#   'isCountable': True,
#   'dateCreate': '2024-04-03 18:32:59',
#   'resolutionIsApproved': None,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nПодобрать удобный для себя офис или банкомат можно в Сбербанк Онлайн или на нашем сайте: https://www.sberbank.com/ru/oib?tab=vsp Там всегда актуальная информация.\r\nЧто касается ошибки в объявлении, напишите, пожалуйста, полный адрес в комментариях, попрошу коллег исправить\r\n\r\nС уважением, \r\nМария Александрова\r\nСбер',
#   'agentId': 322,
#   'company': {'id': 322,
#    'code': 'sberbank',
#    'name': 'Сбербанк',
#    'url': 'sberbank',
#    'logo': '//static3.banki.ru/ugc/30/46/f1/aa/322.svg',
#    'squareLogo': '//static3.banki.ru/ugc/9d/12/0b/81/322.png',
#    'phone': [{'phone': '900', 'phone_description': 'единая справочная служба'},
#     {'phone': '0321',
#      'phone_description': 'для корпоративных клиентов; бесплатные звонки с мобильных телефонов (Билайн, Мегафон, МТС, Tele2) на территории России'},
#     {'phone': '8 800 555-55-50',
#      'phone_description': 'единая справочная служба; для бесплатных звонков абонентов сотовых операторов МТС, Билайн, Мегафон, Tele2, Yota и Мотив из всех регионов России'},
#     {'phone': '8 800 555-57-77',
#      'phone_description': 'для корпоративных клиентов; бесплатные звонки с городских телефонов на территории России'}],
#    'region': 'Москва',
#    'address': '117997, г.\xa0Москва, ул.\xa0Вавилова, д.\xa019'}},
#  {'id': 11425285,
#   'title': 'Самый отвратительный банк!',
#   'userName': 'DELETED',
#   'text': '<p>Никогда таких проблем с другими банками не имела, как с МТС Банком! Оформляла рефинансирование, сделала ЧДП 12.03.2024, все списалось вовремя и в том объеме, в котором было заявлено, но потом начались какие-то проблемы. \r\n\r\nПосле ЧДП у меня образовалась по непонятным причинам просроченная задолженность, какие-то неуплаченные % и еще пени на них стали начислять считаю каждый день! Мне стали звонить сотрудники, сыпаться грозные СМС. \r\n\r\nЯ написала в поддержку и с сотрудником онлайн-чата создали заявку 14.03.2024 , которую долго не могли решить и решают по сей день. 01.04.2024 я получила СМС о том, что заявка исполнена, но ситуация не изменилась! В ЛК так же "светится" строка "просрочен платеж". Мне как продолжали звонить и сыпаться грозные СМС, так и продолжают до сих пор! \r\n\r\nПочему я должна страдать из-за технической ошибки этого банка? Скоро будет очередной ежемесячный платеж и первым, то у меня спишут, это эти незаконно начисленные проценты и пени! Почему из-за технической ошибки банка я должна платить неоьоснованно начисленную сумму процентов и пеней из своего кармана? Абсолютное возмущение и полное нежелание дальше быть клиентом МТС Банка.\xa0</p>',
#   'grade': 2,
#   'commentCount': 1,
#   'isCountable': True,
#   'dateCreate': '2024-04-03 16:38:46',
#   'resolutionIsApproved': True,
#   'agentAnswerText': 'Здравствуйте, Kh.V.A!\r\n\r\nВозьмем некоторое время, чтобы все проверить по кредиту. И чуть позже вернемся с ответом.\r\n\r\nС уважением,\r\nМТС Банк',
#   'agentId': 6055,
#   'company': {'id': 6055,
#    'code': 'mts-bank',
#    'name': 'МТС Банк',
#    'url': 'mts-bank',
#    'logo': '//static2.banki.ru/ugc/7f/af/89/78/6055.svg',
#    'squareLogo': '//static2.banki.ru/ugc/b4/10/85/f8/6055.png',
#    'phone': [{'phone': '8 800 250-05-20',
#      'phone_description': 'служба поддержки держателей банковских карт'}],
#    'region': 'Москва',
#    'address': '115432, г.\xa0Москва, просп. Андропова, д.\xa018, корп. 1'}},
#  {'id': 11425245,
#   'title': 'Не начислена выплата по акции "Бонусы за использование Unionpay Газпромбанка.2"',
#   'userName': 'user-583017621082',
#   'text': '<p>22 ноября 2023 заказала карту Unionpay. Списали 5000 рублей за использование. В ноябре, декабре и январе были совершены покупки от 10000 рублей. Ожидала, что в феврале начислят бонус в 5000 рублей согласно условиям акции, но этого не произошло. На вопрос о том, почему не был выплачен бонус, в чате просто скинули условия акции (причём некорректные для моей карты) и тут же закрыли вопрос. Я ведь потому и спросила, что условия изучила, а причины невыплаты мне так и остались неясными. \r\n\r\nДалее последовали попытки дозвониться до банка (ожидание просто зашкаливало, а чат просто несколько дней не брал вопросы в работу), наконец удалось это сделать, там оператор подтвердила, что условия акции были выполнены и зарегистрировала обращение 1650355.  Через 10 дней мне пришёл ответ, что по техническим причинам я не вошла в список участников акции, что банк работает над этим и начислит выплату до конца месяца, если условия были выполнены. Март закончился, выплаты нет, информации также не поступало. Очень разочарована взаимодействием с банком и отсутствием адекватной обратной связи.\xa0</p>',
#   'grade': 1,
#   'commentCount': 3,
#   'isCountable': True,
#   'dateCreate': '2024-04-03 16:14:23',
#   'resolutionIsApproved': True,
#   'agentAnswerText': 'Здравствуйте!\r\n\r\nНам жаль, что вам пришлось столкнуться с такими сложностями. \r\nПроверим информацию по вашему обращению и обязательно вернемся с ответом.\r\n\r\nС уважением,\r\nКоманда экспертов Газпромбанка',
#   'agentId': 2764,
#   'company': {'id': 2764,
#    'code': 'gazprombank',
#    'name': 'Газпромбанк',
#    'url': 'gazprombank',
#    'logo': '//static4.banki.ru/ugc/47/e1/79/0a/2764.svg',
#    'squareLogo': '//static4.banki.ru/ugc/6d/43/60/de/2764.png',
#    'phone': [{'phone': '400', 'phone_description': None},
#     {'phone': '8 800 300-60-90', 'phone_description': None},
#     {'phone': '8 800 100-07-01', 'phone_description': None},
#     {'phone': '* 6090',
#      'phone_description': 'для абонентов МТС, Билайн, Мегафон, Tele2 и Мотив'}],
#    'region': 'Москва',
#    'address': '117420, г.\xa0Москва, ул.\xa0Наметкина, д.\xa016, корп. 1.'}}]
